# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Most-Recent-Cohorts-Institution.csv", low_memory=False)

# %%
#df_liberal_arts = df[df["CCBASIC"] == 21]

# %%
fields_to_filter = pd.read_csv("CollegeScorecard_fields.csv", header=None)

# %%
type(fields_to_filter[0])
# Out:
# pandas.core.series.Series

# %%
df_filtered = df[fields_to_filter[0]]

# %%
df_filtered
# Out:
#         UNITID                                             INSTNM        CITY  \
# 0       100654                           Alabama A & M University      Normal
# 1       100663                University of Alabama at Birmingham  Birmingham
# 2       100690                                 Amridge University  Montgomery
# 3       100706                University of Alabama in Huntsville  Huntsville
# 4       100724                           Alabama State University  Montgomery
# ...        ...                                                ...         ...
# 6538  49576720      Pennsylvania State University-Penn State York        York
# 6539  49576721  Pennsylvania State University-Penn State Great...     Malvern
# 6540  49576722  Pennsylvania State University-Penn State Harri...  Middletown
# 6541  49576723  Pennsylvania State University-Penn State Brand...       Media
# 6542  49664501  Burlington County Institute of Technology - Ad...     Medford
#
# ...

# %%
df_filtered.to_csv("college_scorecard_2023.csv")

# %%
print(df_filtered.columns)
# Out:
# Index(['UNITID', 'INSTNM', 'CITY', 'STABBR', 'ZIP', 'INSTURL', 'HIGHDEG',
#        'CONTROL', 'ST_FIPS', 'REGION',
#        ...
#        'PRGMOFR', 'BOOKSUPPLY', 'ROOMBOARD_ON', 'OTHEREXPENSE_ON',
#        'ROOMBOARD_OFF', 'OTHEREXPENSE_OFF', 'OTHEREXPENSE_FAM', 'ENDOWBEGIN',
#        'ENDOWEND', 'ADMCON7'],
#       dtype='object', length=115)
